# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %matplotlib inline

# %%
DATAPATH=Path('./data')
assert DATAPATH.exists()
INTERIM=DATAPATH/'interim'
assert INTERIM.exists()

# %% [markdown]
# ## Running Back

# %%
rb = pd.read_csv(INTERIM/'rb_fp_season_psk.csv')
rb.head()
# Out:
#                Player Id  Year  Rushing Yards pts sum  Rushing Yards pts mean  \
# 0  ameerabdullah/2552374  2017                   55.2                3.942857
# 1  ameerabdullah/2552374  2016                   10.1                5.050000
# 2  ameerabdullah/2552374  2015                   59.7                3.731250
# 3       jayajayi/2552582  2017                   87.3                6.235714
# 4       jayajayi/2552582  2016                  127.2                8.480000
#
#    Receiving Yards pts sum  Receiving Yards pts mean  Rushing TDs pts sum  \
# 0                     16.2                  1.246154                 24.0
# 1                      5.7                  5.700000                  0.0
# 2                     18.3                  1.220000                 12.0
# 3                     15.8                  1.215385                  6.0
# 4                     15.1                  1.258333                 48.0
#
# ...

# %%
rb[rb['Year'] == 2017].sort_values()
